# %%
import cv2
import matplotlib.pyplot as plt
import seaborn as sns; 
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from mpl_toolkits import mplot3d
from pylab import savefig

# %%
img = plt.imread("./1.png")
reconstruction = np.load("./1_reconstruction.npy")
features = np.load("./1_features.npy")

# %%
plt.imshow(img)

# %%
error = np.abs(features-reconstruction)
error = np.sum(error, axis=-1)
mean = np.mean(error)
sns.heatmap(error, center=mean)
# Out:
# <AxesSubplot:>

# %%
img = plt.imread("./2.png")
reconstruction = np.load("./2_reconstruction.npy")
features = np.load("./2_features.npy")

# %%
plt.imshow(img)

# %%
error = np.abs(features-reconstruction)
error = np.sum(error, axis=-1)
mean = np.mean(error)
sns.heatmap(error, center=mean)
# Out:
# <AxesSubplot:>
