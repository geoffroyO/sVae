# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img = plt.imread("./6.jpg")
img = img.astype('float32') / 255.
mask = plt.imread("./5_gt.png")
plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-50-0003c86a4158> in <module>
# ----> 1 img = plt.imread("./12.jpg")
#       2 img = img.astype('float32') / 255.
#       3 mask = plt.imread("./5_gt.png")
#       4 plt.imshow(img)
#
# ~/anaconda3/envs/tf/lib/python3.8/site-packages/matplotlib/pyplot.py in imread(fname, format)
#    2244 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2245 def imread(fname, format=None):
# -> 2246     return matplotlib.image.imread(fname, format)
#    2247
#    2248
#
# ~/anaconda3/envs/tf/lib/python3.8/site-packages/matplotlib/image.py in imread(fname, format)
#    1494                     response = io.BytesIO(response.read())
#    1495                 return imread(response, format=ext)
# -> 1496     with img_open(fname) as image:
#    1497         return (_pil_png_to_float_array(image)
# ...

# %%
mask.shape
# Out:
# (384, 256, 4)

# %%
n, m, _ = mask.shape
indexTamp = []
for i in range(n):
    for j in range(m):
        if mask[i, j, 0] == 1:
            indexTamp.append((i, j))

# %%
for sig in range(0, 30, 1):
    noisy = np.copy(img)
    mu, sigma = 0, sig/100
    for i, j in indexTamp:
        noise = np.random.normal(mu, sigma, 3)
        noisy[i, j,:] += noise
        for ch in range(3):
            if noisy[i, j, ch] < 0:
                noisy[i, j, ch] = 0
            elif noisy[i, j, ch] > 1:
                noisy[i, j, ch] = 1
    plt.imsave("./5_{}.jpg".format(sigma), noisy, format='jpg')

# %%
plt.imshow(noisy)
